# %% [markdown]
# ## This file makes machine learning application for individual packets for Aalto University.
# ### Used machine learning algorithms: RF (Random Forest) DT (Decision Trees)

# %% [markdown]
# ###  importing relevant libraries

# %%
# %matplotlib inline
from numpy import array
from random import random
from sklearn import metrics
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis as QDA
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.metrics import average_precision_score
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import BernoulliNB#57
from sklearn.naive_bayes import GaussianNB#52
from sklearn.naive_bayes import MultinomialNB#56
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score
import csv
import math
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import sklearn
import time
import warnings
warnings.filterwarnings("ignore")
from sklearn.metrics import classification_report

# %% [markdown]
# ### Discovering dataset

# %%
def find_the_way(path,file_format):
    files_add = []
    # r=root, d=directories, f = files
    for r, d, f in os.walk(path):
        for file in f:
            if file_format in file:
                files_add.append(os.path.join(r, file))  
    return files_add
files_add=find_the_way('./dataset/','.csv')
files_add
# Out:
# ['./dataset/Main_Sentinel.csv',
#  './dataset/IPAssess_Sentinel_Accuracy.csv',
#  './dataset/Main_Sentinel_padding_ralert.csv',
#  './dataset/IPAssess_Sentinel.csv']

# %% [markdown]
# ### Discovering Labels

# %%
def target_names():
    name=files_add[2]
    df = pd.read_csv(name)
    target_names=sorted(list(df[df.columns[-2]].unique()))
    return target_names
target_names=target_names()
len(target_names)
# Out:
# 25

# %%
target_names
# Out:
# ['Aria',
#  'D-LinkCam',
#  'D-LinkDayCam',
#  'D-LinkDevice',
#  'D-LinkSensor',
#  'D-LinkSiren',
#  'D-LinkSwitch',
#  'D-LinkWaterSensor',
#  'EdimaxCam',
#  'EdimaxPlug1101W',
#  'EdimaxPlug2101W',
#  'EdnetCam',
#  'EdnetGateway',
#  'HomeMaticPlug',
#  'Hue-Device',
#  'Lightify',
#  'MAXGateway',
#  'SmarterCoffee',
#  'TP-LinkPlugHS100',
#  'TP-LinkPlugHS110',
#  'WeMoInsightSwitch',
#  'WeMoLink',
#  'WeMoSwitch',
#  'Withings',
#  'iKettle2']

# %% [markdown]
# ### Hyperparameters of machine learning algorithms

# %%
ml_list={
"DT_r":DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=22,
                       max_features=1.0, max_leaf_nodes=None,
                       min_impurity_decrease=0.0, 
                       min_samples_leaf=1, min_samples_split=4,
                       min_weight_fraction_leaf=0.0,
                       random_state=None, splitter='best'),  
 "Random Forest R":RandomForestClassifier(bootstrap=True, class_weight=None, criterion='entropy',
                       max_depth=27, max_features=1, max_leaf_nodes=None,
                       min_impurity_decrease=0.0,
                       min_samples_leaf=1, min_samples_split=10,
                       min_weight_fraction_leaf=0.0, n_estimators=69,
                       n_jobs=None, oob_score=False, random_state=None,
                       verbose=0, warm_start=False)}

# %% [markdown]
# ### This part is the main part of the file. Cross-validates the respective datasets 10-time 10-fold and prints the results (general results, class-based results and confusion matrix).

# %%
ths = open("dataset/IPAssess_Sentinel_Accuracy.csv", "w")
ths.write("Dataset,T,CV,ML algorithm,Acc,b_Acc,Precision, Recall , F1-score, kappa ,tra-Time,test-Time,total-Time))\n")
repetition=10


from sklearn.metrics import balanced_accuracy_score
from sklearn.preprocessing import Normalizer
print ('%-15s %-3s %-3s %-6s  %-5s %-5s %-5s %-5s %-5s %-5s %-8s %-8s%-8s'%
           ("Dataset","T","CV","ML alg","Acc","b_Acc","Prec", "Rec" , "F1", "kap" ,"tra-T","test-T","total"))
curr_file=[]
curr_file.append(files_add[2])
for loop in curr_file:
    for ii in ml_list:
        class_based_results=pd.DataFrame()#"" #pd.DataFrame(0, index=np.arange((len(target_names)+3)), columns=["f1-score","precision","recall","support"])
        cm=pd.DataFrame()
        for i in range(repetition):
            rnd = random()
            kfold = KFold(n_splits=10, shuffle=True, random_state=int(rnd*100))  
            cv=0
            df = pd.read_csv(loop)#,header=None )
            del df["MAC"] # if dataset has MAC colomn please uncomment this line
            X =df[df.columns[0:-1]]
            X=np.array(X)
            df[df.columns[-1]] = df[df.columns[-1]].astype('category')
            y=df[df.columns[-1]].cat.codes  
            #scaler = Normalizer().fit(X)
            #X = scaler.transform(X)
            # summarize transformed data
            dname=loop[7:-4]
            X.shape
            for train_index, test_index in kfold.split(X):
                results_y=[]
                X_train, X_test = X[train_index], X[test_index]
                y_train, y_test = y[train_index], y[test_index]  
                cv+=1
                results_y.append(y_test)


                precision=[]
                recall=[]
                f1=[]
                accuracy=[]
                train_time=[]
                test_time=[]
                total_time=[]
                kappa=[]
                accuracy_b=[]
                    #machine learning algorithm is applied in this section
                clf = ml_list[ii]#choose algorithm from ml_list dictionary
                second=time.time()
                clf.fit(X_train, y_train)
                train_time.append(float((time.time()-second)) )
                second=time.time()
                predict =clf.predict(X_test)
                test_time.append(float((time.time()-second)) )

                rc=sklearn.metrics.recall_score(y_test, predict,average= "macro")
                pr=sklearn.metrics.precision_score(y_test, predict,average= "macro")
                f_1=sklearn.metrics.f1_score(y_test, predict,average= "macro")        
                report = classification_report(y_test, predict, target_names=target_names,output_dict=True)
                cr = pd.DataFrame(report).transpose()
                if class_based_results.empty:
                    class_based_results =cr
                else:
                    class_based_results = class_based_results.add(cr, fill_value=0)
                precision.append(float(pr))
                recall.append(float(rc))
                f1.append(float(f_1))
                accuracy_b.append(balanced_accuracy_score( y_test,predict))
                accuracy.append(accuracy_score(y_test, predict))
                #clf.score(X_test, y_test))
                #print(balanced_accuracy_score( y_test,predict))
                #t_time.append(float((time.time()-second)) )
                kappa.append(round(float(sklearn.metrics.cohen_kappa_score(y_test, predict, 
                labels=None, weights=None, sample_weight=None)),15))
                print ('%-15s %-3s %-3s %-6s  %-5s %-5s %-5s %-5s %-5s %-5s %-8s %-8s%-8s' % (dname,i,cv,ii[0:6],str(round(np.mean(accuracy),2)),str(round(np.mean(accuracy_b),2)),
                    str(round(np.mean(precision),2)), str(round(np.mean(recall),2)),str(round(np.mean(f1),2)), 
                    str(round(np.mean(kappa),2)),str(round(np.mean(train_time),2)),str(round(np.mean(test_time),2)),str(round(np.mean(test_time)+np.mean(train_time),2))))
                lines=(str(dname)+","+str(i)+","+str(cv)+","+str(ii)+","+str(round(np.mean(accuracy),15))+","+str(round(np.mean(accuracy_b),15))+","+str(round(np.mean(precision),15))+","+ str(round(np.mean(recall),15))+","+str(round(np.mean(f1),15))+","+str(round(np.mean(kappa),15))+","+str(round(np.mean(train_time),15))+","+str(round(np.mean(test_time),15))+","+str(round(np.mean(test_time)+np.mean(train_time),15))+"\n")

                ths.write (lines)

                df_cm = pd.DataFrame(confusion_matrix(y_test, predict))
                results_y.append(predict)
                if cm.empty:
                    cm =df_cm
                else:
                    cm = cm.add(df_cm, fill_value=0)
 
        print(class_based_results/100) 
        cm=cm/100
        graph_name="confusion matrix" +str(ii)       
        plt.figure(figsize = (20,14))
        sns.heatmap(cm,xticklabels=target_names, yticklabels=target_names, annot=True)
        plt.savefig(graph_name,bbox_inches='tight')#, dpi=400)
        plt.show()
        #print(cm)
        print("\n\n\n") 
ths.close()
# Out:
# Dataset         T   CV  ML alg  Acc   b_Acc Prec  Rec   F1    kap   tra-T    test-T  total
# et/Main_Sentinel_padding_ralert 0   1   DT_r    0.78  0.66  0.69  0.66  0.67  0.74  0.14     0.0     0.14
# et/Main_Sentinel_padding_ralert 0   2   DT_r    0.78  0.65  0.69  0.65  0.67  0.74  0.13     0.0     0.13
# et/Main_Sentinel_padding_ralert 0   3   DT_r    0.78  0.66  0.7   0.66  0.68  0.74  0.13     0.0     0.13
# et/Main_Sentinel_padding_ralert 0   4   DT_r    0.77  0.65  0.71  0.65  0.67  0.74  0.13     0.0     0.13
# et/Main_Sentinel_padding_ralert 0   5   DT_r    0.78  0.66  0.71  0.66  0.68  0.75  0.13     0.0     0.13
# et/Main_Sentinel_padding_ralert 0   6   DT_r    0.78  0.67  0.7   0.67  0.68  0.75  0.13     0.0     0.13
# et/Main_Sentinel_padding_ralert 0   7   DT_r    0.77  0.65  0.68  0.65  0.66  0.74  0.13     0.0     0.13
# et/Main_Sentinel_padding_ralert 0   8   DT_r    0.78  0.67  0.71  0.67  0.68  0.75  0.13     0.0     0.13
# et/Main_Sentinel_padding_ralert 0   9   DT_r    0.78  0.66  0.7   0.66  0.67  0.75  0.13     0.0     0.13
# et/Main_Sentinel_padding_ralert 0   10  DT_r    0.78  0.65  0.69  0.65  0.66  0.74  0.13     0.0     0.13
# et/Main_Sentinel_padding_ralert 1   1   DT_r    0.78  0.65  0.69  0.65  0.66  0.74  0.13     0.0     0.13
# et/Main_Sentinel_padding_ralert 1   2   DT_r    0.78  0.65  0.7   0.65  0.67  0.74  0.13     0.0     0.13
# et/Main_Sentinel_padding_ralert 1   3   DT_r    0.78  0.67  0.71  0.67  0.69  0.75  0.13     0.0     0.13
# et/Main_Sentinel_padding_ralert 1   4   DT_r    0.78  0.66  0.7   0.66  0.68  0.75  0.13     0.0     0.13
# et/Main_Sentinel_padding_ralert 1   5   DT_r    0.78  0.66  0.71  0.66  0.68  0.75  0.13     0.0     0.13
# et/Main_Sentinel_padding_ralert 1   6   DT_r    0.78  0.66  0.7   0.66  0.67  0.75  0.13     0.0     0.13
# et/Main_Sentinel_padding_ralert 1   7   DT_r    0.78  0.66  0.71  0.66  0.68  0.74  0.13     0.0     0.13
# et/Main_Sentinel_padding_ralert 1   8   DT_r    0.78  0.65  0.72  0.65  0.67  0.74  0.13     0.0     0.14
# et/Main_Sentinel_padding_ralert 1   9   DT_r    0.79  0.65  0.69  0.65  0.66  0.75  0.13     0.0     0.13
# et/Main_Sentinel_padding_ralert 1   10  DT_r    0.78  0.65  0.7   0.65  0.66  0.74  0.13     0.0     0.13
# et/Main_Sentinel_padding_ralert 2   1   DT_r    0.78  0.66  0.71  0.66  0.67  0.75  0.13     0.0     0.13
# et/Main_Sentinel_padding_ralert 2   2   DT_r    0.78  0.66  0.72  0.66  0.68  0.74  0.13     0.0     0.13
# et/Main_Sentinel_padding_ralert 2   3   DT_r    0.78  0.65  0.69  0.65  0.67  0.75  0.13     0.0     0.13
# et/Main_Sentinel_padding_ralert 2   4   DT_r    0.78  0.66  0.72  0.66  0.68  0.75  0.13     0.0     0.13
# et/Main_Sentinel_padding_ralert 2   5   DT_r    0.77  0.64  0.69  0.64  0.66  0.74  0.13     0.0     0.13
# et/Main_Sentinel_padding_ralert 2   6   DT_r    0.78  0.65  0.71  0.65  0.67  0.75  0.13     0.0     0.13
# et/Main_Sentinel_padding_ralert 2   7   DT_r    0.78  0.65  0.7   0.65  0.66  0.74  0.13     0.0     0.13
# et/Main_Sentinel_padding_ralert 2   8   DT_r    0.79  0.66  0.7   0.66  0.68  0.76  0.13     0.0     0.13
# et/Main_Sentinel_padding_ralert 2   9   DT_r    0.78  0.66  0.71  0.66  0.68  0.75  0.13     0.0     0.14
# et/Main_Sentinel_padding_ralert 2   10  DT_r    0.78  0.66  0.7   0.66  0.67  0.74  0.13     0.0     0.13
# et/Main_Sentinel_padding_ralert 3   1   DT_r    0.77  0.64  0.69  0.64  0.66  0.74  0.13     0.0     0.13
# et/Main_Sentinel_padding_ralert 3   2   DT_r    0.78  0.66  0.71  0.66  0.68  0.75  0.13     0.0     0.13
# et/Main_Sentinel_padding_ralert 3   3   DT_r    0.78  0.66  0.72  0.66  0.68  0.75  0.13     0.0     0.13
# et/Main_Sentinel_padding_ralert 3   4   DT_r    0.77  0.65  0.68  0.65  0.66  0.74  0.13     0.0     0.14
# et/Main_Sentinel_padding_ralert 3   5   DT_r    0.78  0.66  0.69  0.66  0.67  0.75  0.13     0.0     0.13
# et/Main_Sentinel_padding_ralert 3   6   DT_r    0.78  0.66  0.73  0.66  0.69  0.75  0.13     0.0     0.13
# et/Main_Sentinel_padding_ralert 3   7   DT_r    0.78  0.66  0.69  0.66  0.67  0.75  0.13     0.0     0.13
# et/Main_Sentinel_padding_ralert 3   8   DT_r    0.77  0.65  0.7   0.65  0.67  0.74  0.13     0.0     0.13
# et/Main_Sentinel_padding_ralert 3   9   DT_r    0.78  0.66  0.7   0.66  0.68  0.75  0.13     0.0     0.13
# et/Main_Sentinel_padding_ralert 3   10  DT_r    0.78  0.65  0.7   0.65  0.67  0.75  0.13     0.0     0.13
# et/Main_Sentinel_padding_ralert 4   1   DT_r    0.78  0.65  0.69  0.65  0.66  0.74  0.13     0.0     0.13
# et/Main_Sentinel_padding_ralert 4   2   DT_r    0.78  0.66  0.7   0.66  0.67  0.74  0.13     0.0     0.14
# et/Main_Sentinel_padding_ralert 4   3   DT_r    0.78  0.67  0.71  0.67  0.69  0.75  0.13     0.0     0.13
# et/Main_Sentinel_padding_ralert 4   4   DT_r    0.78  0.66  0.7   0.66  0.68  0.75  0.13     0.0     0.13
# et/Main_Sentinel_padding_ralert 4   5   DT_r    0.78  0.66  0.71  0.66  0.68  0.75  0.13     0.0     0.13
# et/Main_Sentinel_padding_ralert 4   6   DT_r    0.78  0.66  0.7   0.66  0.67  0.75  0.13     0.0     0.13
# et/Main_Sentinel_padding_ralert 4   7   DT_r    0.78  0.66  0.71  0.66  0.68  0.74  0.13     0.0     0.13
# et/Main_Sentinel_padding_ralert 4   8   DT_r    0.78  0.65  0.72  0.65  0.67  0.74  0.13     0.0     0.14
# et/Main_Sentinel_padding_ralert 4   9   DT_r    0.78  0.65  0.69  0.65  0.66  0.75  0.13     0.0     0.13
# et/Main_Sentinel_padding_ralert 4   10  DT_r    0.78  0.65  0.7   0.65  0.66  0.74  0.13     0.0     0.13
# et/Main_Sentinel_padding_ralert 5   1   DT_r    0.77  0.66  0.69  0.66  0.67  0.74  0.13     0.0     0.13
# et/Main_Sentinel_padding_ralert 5   2   DT_r    0.78  0.65  0.7   0.65  0.67  0.74  0.13     0.0     0.13
# et/Main_Sentinel_padding_ralert 5   3   DT_r    0.78  0.65  0.71  0.65  0.66  0.74  0.14     0.0     0.14
# et/Main_Sentinel_padding_ralert 5   4   DT_r    0.78  0.67  0.71  0.67  0.68  0.75  0.13     0.0     0.13
# et/Main_Sentinel_padding_ralert 5   5   DT_r    0.78  0.67  0.71  0.67  0.69  0.75  0.13     0.0     0.13
# et/Main_Sentinel_padding_ralert 5   6   DT_r    0.79  0.65  0.69  0.65  0.66  0.75  0.13     0.0     0.13
# et/Main_Sentinel_padding_ralert 5   7   DT_r    0.78  0.66  0.72  0.66  0.68  0.75  0.13     0.0     0.13
# et/Main_Sentinel_padding_ralert 5   8   DT_r    0.77  0.65  0.69  0.65  0.66  0.74  0.13     0.0     0.13
# et/Main_Sentinel_padding_ralert 5   9   DT_r    0.78  0.66  0.71  0.66  0.68  0.75  0.13     0.0     0.13
# et/Main_Sentinel_padding_ralert 5   10  DT_r    0.78  0.65  0.69  0.65  0.67  0.74  0.13     0.0     0.13
# et/Main_Sentinel_padding_ralert 6   1   DT_r    0.77  0.66  0.7   0.66  0.67  0.74  0.13     0.0     0.13
# et/Main_Sentinel_padding_ralert 6   2   DT_r    0.78  0.65  0.7   0.65  0.67  0.75  0.13     0.0     0.13
# et/Main_Sentinel_padding_ralert 6   3   DT_r    0.78  0.66  0.72  0.66  0.68  0.75  0.13     0.0     0.13
# et/Main_Sentinel_padding_ralert 6   4   DT_r    0.77  0.65  0.71  0.65  0.67  0.74  0.13     0.0     0.13
# et/Main_Sentinel_padding_ralert 6   5   DT_r    0.78  0.67  0.71  0.67  0.68  0.75  0.13     0.0     0.13
# et/Main_Sentinel_padding_ralert 6   6   DT_r    0.77  0.66  0.69  0.66  0.67  0.74  0.13     0.0     0.13
# et/Main_Sentinel_padding_ralert 6   7   DT_r    0.78  0.65  0.69  0.65  0.67  0.74  0.13     0.0     0.13
# et/Main_Sentinel_padding_ralert 6   8   DT_r    0.78  0.66  0.7   0.66  0.68  0.75  0.13     0.0     0.14
# et/Main_Sentinel_padding_ralert 6   9   DT_r    0.78  0.65  0.71  0.65  0.66  0.74  0.13     0.0     0.13
# et/Main_Sentinel_padding_ralert 6   10  DT_r    0.78  0.65  0.7   0.65  0.66  0.75  0.13     0.0     0.13
# et/Main_Sentinel_padding_ralert 7   1   DT_r    0.78  0.66  0.72  0.66  0.68  0.75  0.13     0.0     0.13
# et/Main_Sentinel_padding_ralert 7   2   DT_r    0.78  0.65  0.7   0.65  0.67  0.74  0.13     0.0     0.13
# et/Main_Sentinel_padding_ralert 7   3   DT_r    0.78  0.66  0.7   0.66  0.68  0.75  0.13     0.0     0.14
# et/Main_Sentinel_padding_ralert 7   4   DT_r    0.78  0.66  0.69  0.66  0.67  0.74  0.13     0.0     0.13
# et/Main_Sentinel_padding_ralert 7   5   DT_r    0.78  0.64  0.7   0.64  0.66  0.74  0.13     0.0     0.13
# et/Main_Sentinel_padding_ralert 7   6   DT_r    0.79  0.66  0.7   0.66  0.67  0.75  0.13     0.0     0.13
# et/Main_Sentinel_padding_ralert 7   7   DT_r    0.78  0.66  0.69  0.66  0.67  0.74  0.13     0.0     0.13
# et/Main_Sentinel_padding_ralert 7   8   DT_r    0.78  0.65  0.7   0.65  0.67  0.75  0.13     0.0     0.13
# et/Main_Sentinel_padding_ralert 7   9   DT_r    0.78  0.65  0.69  0.65  0.67  0.74  0.13     0.0     0.13
# et/Main_Sentinel_padding_ralert 7   10  DT_r    0.78  0.67  0.72  0.67  0.69  0.75  0.13     0.0     0.13
# et/Main_Sentinel_padding_ralert 8   1   DT_r    0.77  0.65  0.7   0.65  0.67  0.74  0.13     0.0     0.13
# et/Main_Sentinel_padding_ralert 8   2   DT_r    0.78  0.64  0.71  0.64  0.66  0.74  0.13     0.0     0.13
# et/Main_Sentinel_padding_ralert 8   3   DT_r    0.78  0.66  0.7   0.66  0.67  0.75  0.13     0.0     0.13
# et/Main_Sentinel_padding_ralert 8   4   DT_r    0.78  0.65  0.7   0.65  0.66  0.74  0.13     0.0     0.14
# et/Main_Sentinel_padding_ralert 8   5   DT_r    0.78  0.66  0.7   0.66  0.68  0.75  0.13     0.0     0.13
# et/Main_Sentinel_padding_ralert 8   6   DT_r    0.78  0.67  0.72  0.67  0.69  0.74  0.13     0.0     0.13
# et/Main_Sentinel_padding_ralert 8   7   DT_r    0.78  0.66  0.71  0.66  0.68  0.74  0.13     0.0     0.13
# et/Main_Sentinel_padding_ralert 8   8   DT_r    0.79  0.66  0.7   0.66  0.67  0.75  0.13     0.0     0.13
# et/Main_Sentinel_padding_ralert 8   9   DT_r    0.79  0.66  0.7   0.66  0.68  0.75  0.13     0.0     0.13
# et/Main_Sentinel_padding_ralert 8   10  DT_r    0.78  0.66  0.71  0.66  0.68  0.74  0.13     0.0     0.13
# et/Main_Sentinel_padding_ralert 9   1   DT_r    0.77  0.64  0.73  0.64  0.67  0.74  0.13     0.0     0.13
# et/Main_Sentinel_padding_ralert 9   2   DT_r    0.78  0.66  0.72  0.66  0.68  0.74  0.13     0.0     0.13
# et/Main_Sentinel_padding_ralert 9   3   DT_r    0.78  0.66  0.71  0.66  0.68  0.75  0.14     0.0     0.14
# et/Main_Sentinel_padding_ralert 9   4   DT_r    0.78  0.64  0.69  0.64  0.66  0.74  0.14     0.0     0.14
# et/Main_Sentinel_padding_ralert 9   5   DT_r    0.78  0.67  0.7   0.67  0.68  0.75  0.13     0.0     0.13
# et/Main_Sentinel_padding_ralert 9   6   DT_r    0.78  0.66  0.72  0.66  0.68  0.75  0.13     0.0     0.13
# et/Main_Sentinel_padding_ralert 9   7   DT_r    0.78  0.65  0.72  0.65  0.68  0.74  0.13     0.0     0.13
# et/Main_Sentinel_padding_ralert 9   8   DT_r    0.78  0.65  0.69  0.65  0.67  0.75  0.13     0.0     0.13
# et/Main_Sentinel_padding_ralert 9   9   DT_r    0.78  0.66  0.7   0.66  0.67  0.74  0.13     0.0     0.13
# et/Main_Sentinel_padding_ralert 9   10  DT_r    0.78  0.67  0.7   0.67  0.68  0.74  0.13     0.0     0.13
#                    precision    recall  f1-score       support
# Aria                0.820593  0.763631  0.789027     52.000000
# D-LinkCam           0.862001  0.906982  0.883811    635.800000
# D-LinkDayCam        0.895199  0.796987  0.842214    123.500000
# D-LinkDevice        0.759479  0.811545  0.784412   1067.800000
# D-LinkSensor        0.473427  0.404922  0.436048    663.300000
# D-LinkSiren         0.417334  0.366561  0.389482    628.900000
# D-LinkSwitch        0.634959  0.583671  0.607860    661.400000
# D-LinkWaterSensor   0.459597  0.491581  0.474512    653.800000
# EdimaxCam           0.925507  0.778432  0.844068     89.600000
# EdimaxPlug1101W     0.495265  0.529957  0.509679    124.700000
# EdimaxPlug2101W     0.392047  0.393653  0.389046    113.100000
# EdnetCam            0.867454  0.610665  0.713242     39.000000
# EdnetGateway        0.792745  0.653390  0.714026     85.000000
# HomeMaticPlug       0.997850  0.956448  0.976509     63.900000
# Hue-Device          0.981085  0.988301  0.984677   3258.100000
# Lightify            0.627652  0.974408  0.763368    438.400000
# MAXGateway          0.943320  0.872699  0.905835     63.400000
# SmarterCoffee       0.248822  0.138468  0.170549     19.000000
# TP-LinkPlugHS100    0.653281  0.544259  0.591620     72.900000
# TP-LinkPlugHS110    0.631446  0.554852  0.587732     69.800000
# WeMoInsightSwitch   0.829568  0.821033  0.824975    607.700000
# WeMoLink            0.910134  0.855062  0.881649    676.900000
# WeMoSwitch          0.839973  0.777586  0.807296    460.700000
# Withings            0.945733  0.743212  0.831137     77.700000
# iKettle2            0.173675  0.086745  0.107071     18.800000
# accuracy            0.779055  0.779055  0.779055      0.779055
# macro avg           0.703126  0.656202  0.672394  10765.200000
# weighted avg        0.778264  0.779055  0.775686  10765.200000
# et/Main_Sentinel_padding_ralert 0   1   Random  0.78  0.66  0.69  0.66  0.67  0.74  1.96     0.09    2.05
# et/Main_Sentinel_padding_ralert 0   2   Random  0.78  0.66  0.71  0.66  0.68  0.75  2.01     0.08    2.08
# et/Main_Sentinel_padding_ralert 0   3   Random  0.79  0.66  0.69  0.66  0.67  0.75  1.93     0.08    2.01
# et/Main_Sentinel_padding_ralert 0   4   Random  0.79  0.67  0.7   0.67  0.68  0.76  1.96     0.08    2.04
# et/Main_Sentinel_padding_ralert 0   5   Random  0.78  0.65  0.71  0.65  0.67  0.75  1.93     0.08    2.01
# et/Main_Sentinel_padding_ralert 0   6   Random  0.79  0.66  0.7   0.66  0.67  0.75  1.95     0.08    2.03
# et/Main_Sentinel_padding_ralert 0   7   Random  0.79  0.65  0.69  0.65  0.67  0.76  1.96     0.08    2.03
# et/Main_Sentinel_padding_ralert 0   8   Random  0.78  0.67  0.71  0.67  0.69  0.75  1.96     0.08    2.03
# et/Main_Sentinel_padding_ralert 0   9   Random  0.79  0.66  0.69  0.66  0.67  0.76  1.96     0.08    2.04
# et/Main_Sentinel_padding_ralert 0   10  Random  0.78  0.66  0.69  0.66  0.67  0.75  1.95     0.08    2.03
# et/Main_Sentinel_padding_ralert 1   1   Random  0.78  0.66  0.71  0.66  0.67  0.75  1.92     0.08    2.0
# et/Main_Sentinel_padding_ralert 1   2   Random  0.79  0.67  0.7   0.67  0.68  0.76  1.98     0.08    2.06
# et/Main_Sentinel_padding_ralert 1   3   Random  0.78  0.65  0.69  0.65  0.67  0.75  1.97     0.08    2.04
# et/Main_Sentinel_padding_ralert 1   4   Random  0.79  0.66  0.71  0.66  0.68  0.75  1.96     0.08    2.04
# et/Main_Sentinel_padding_ralert 1   5   Random  0.78  0.66  0.71  0.66  0.67  0.75  1.98     0.08    2.05
# et/Main_Sentinel_padding_ralert 1   6   Random  0.78  0.67  0.72  0.67  0.68  0.75  2.0      0.08    2.08
# et/Main_Sentinel_padding_ralert 1   7   Random  0.79  0.67  0.73  0.67  0.69  0.76  1.95     0.08    2.03
# et/Main_Sentinel_padding_ralert 1   8   Random  0.78  0.66  0.69  0.66  0.67  0.74  1.96     0.08    2.04
# et/Main_Sentinel_padding_ralert 1   9   Random  0.78  0.66  0.71  0.66  0.68  0.75  1.97     0.08    2.04
# et/Main_Sentinel_padding_ralert 1   10  Random  0.79  0.66  0.72  0.66  0.68  0.75  1.99     0.08    2.06
# et/Main_Sentinel_padding_ralert 2   1   Random  0.79  0.66  0.71  0.66  0.68  0.76  1.97     0.08    2.05
# et/Main_Sentinel_padding_ralert 2   2   Random  0.78  0.65  0.71  0.65  0.67  0.75  1.96     0.08    2.04
# et/Main_Sentinel_padding_ralert 2   3   Random  0.78  0.66  0.7   0.66  0.67  0.75  2.01     0.08    2.09
# et/Main_Sentinel_padding_ralert 2   4   Random  0.78  0.65  0.69  0.65  0.66  0.74  1.97     0.08    2.05
# et/Main_Sentinel_padding_ralert 2   5   Random  0.79  0.66  0.69  0.66  0.67  0.75  2.0      0.08    2.08
# et/Main_Sentinel_padding_ralert 2   6   Random  0.79  0.68  0.71  0.68  0.69  0.76  1.98     0.08    2.06
# et/Main_Sentinel_padding_ralert 2   7   Random  0.78  0.66  0.73  0.66  0.68  0.74  1.97     0.08    2.05
# et/Main_Sentinel_padding_ralert 2   8   Random  0.78  0.67  0.72  0.67  0.68  0.75  1.95     0.08    2.03
# et/Main_Sentinel_padding_ralert 2   9   Random  0.79  0.67  0.7   0.67  0.68  0.76  1.99     0.08    2.07
# et/Main_Sentinel_padding_ralert 2   10  Random  0.79  0.66  0.7   0.66  0.67  0.76  2.02     0.08    2.09
# et/Main_Sentinel_padding_ralert 3   1   Random  0.79  0.66  0.69  0.66  0.67  0.75  1.94     0.08    2.02
# et/Main_Sentinel_padding_ralert 3   2   Random  0.78  0.65  0.7   0.65  0.67  0.75  1.97     0.08    2.05
# et/Main_Sentinel_padding_ralert 3   3   Random  0.78  0.65  0.7   0.65  0.67  0.75  2.01     0.08    2.09
# et/Main_Sentinel_padding_ralert 3   4   Random  0.78  0.67  0.69  0.67  0.68  0.75  1.96     0.08    2.04
# et/Main_Sentinel_padding_ralert 3   5   Random  0.79  0.66  0.71  0.66  0.68  0.76  1.98     0.08    2.05
# et/Main_Sentinel_padding_ralert 3   6   Random  0.78  0.66  0.7   0.66  0.67  0.75  2.02     0.08    2.09
# et/Main_Sentinel_padding_ralert 3   7   Random  0.79  0.66  0.7   0.66  0.68  0.75  1.97     0.08    2.04
# et/Main_Sentinel_padding_ralert 3   8   Random  0.78  0.65  0.68  0.65  0.66  0.75  1.99     0.08    2.07
# et/Main_Sentinel_padding_ralert 3   9   Random  0.79  0.67  0.71  0.67  0.68  0.75  2.0      0.08    2.08
# et/Main_Sentinel_padding_ralert 3   10  Random  0.79  0.68  0.71  0.68  0.69  0.75  2.0      0.08    2.08
# et/Main_Sentinel_padding_ralert 4   1   Random  0.79  0.66  0.71  0.66  0.67  0.75  1.99     0.08    2.07
# et/Main_Sentinel_padding_ralert 4   2   Random  0.78  0.67  0.69  0.67  0.67  0.75  1.98     0.08    2.06
# et/Main_Sentinel_padding_ralert 4   3   Random  0.78  0.65  0.7   0.65  0.67  0.74  1.99     0.08    2.07
# et/Main_Sentinel_padding_ralert 4   4   Random  0.79  0.67  0.71  0.67  0.68  0.75  1.97     0.08    2.05
# et/Main_Sentinel_padding_ralert 4   5   Random  0.79  0.66  0.7   0.66  0.67  0.75  1.98     0.08    2.06
# et/Main_Sentinel_padding_ralert 4   6   Random  0.79  0.67  0.7   0.67  0.68  0.75  2.0      0.08    2.08
# et/Main_Sentinel_padding_ralert 4   7   Random  0.79  0.65  0.7   0.65  0.67  0.75  1.96     0.08    2.04
# et/Main_Sentinel_padding_ralert 4   8   Random  0.79  0.66  0.71  0.66  0.68  0.75  2.0      0.08    2.08
# et/Main_Sentinel_padding_ralert 4   9   Random  0.79  0.67  0.71  0.67  0.68  0.76  1.95     0.08    2.03
# et/Main_Sentinel_padding_ralert 4   10  Random  0.79  0.67  0.71  0.67  0.69  0.76  1.98     0.08    2.06
# et/Main_Sentinel_padding_ralert 5   1   Random  0.78  0.65  0.68  0.65  0.66  0.74  2.01     0.08    2.09
# et/Main_Sentinel_padding_ralert 5   2   Random  0.79  0.66  0.7   0.66  0.67  0.75  1.97     0.08    2.05
# et/Main_Sentinel_padding_ralert 5   3   Random  0.79  0.66  0.7   0.66  0.68  0.75  1.97     0.08    2.05
# et/Main_Sentinel_padding_ralert 5   4   Random  0.78  0.66  0.68  0.66  0.67  0.75  1.99     0.08    2.07
# et/Main_Sentinel_padding_ralert 5   5   Random  0.78  0.65  0.7   0.65  0.67  0.75  1.99     0.08    2.07
# et/Main_Sentinel_padding_ralert 5   6   Random  0.79  0.67  0.71  0.67  0.69  0.76  1.98     0.08    2.06
# et/Main_Sentinel_padding_ralert 5   7   Random  0.78  0.65  0.69  0.65  0.67  0.74  2.02     0.08    2.1
# et/Main_Sentinel_padding_ralert 5   8   Random  0.79  0.66  0.7   0.66  0.67  0.75  1.99     0.08    2.07
# et/Main_Sentinel_padding_ralert 5   9   Random  0.79  0.66  0.71  0.66  0.68  0.75  1.99     0.08    2.07
# et/Main_Sentinel_padding_ralert 5   10  Random  0.79  0.67  0.7   0.67  0.68  0.76  1.99     0.08    2.07
# et/Main_Sentinel_padding_ralert 6   1   Random  0.78  0.64  0.69  0.64  0.66  0.75  1.98     0.08    2.06
# et/Main_Sentinel_padding_ralert 6   2   Random  0.78  0.65  0.7   0.65  0.67  0.75  2.01     0.08    2.09
# et/Main_Sentinel_padding_ralert 6   3   Random  0.79  0.67  0.7   0.67  0.68  0.76  2.01     0.08    2.09
# et/Main_Sentinel_padding_ralert 6   4   Random  0.78  0.65  0.7   0.65  0.67  0.75  2.03     0.09    2.12
# et/Main_Sentinel_padding_ralert 6   5   Random  0.79  0.67  0.7   0.67  0.68  0.76  2.01     0.08    2.08
# et/Main_Sentinel_padding_ralert 6   6   Random  0.78  0.67  0.7   0.67  0.68  0.75  2.0      0.08    2.08
# et/Main_Sentinel_padding_ralert 6   7   Random  0.78  0.66  0.69  0.66  0.67  0.75  2.0      0.08    2.08
# et/Main_Sentinel_padding_ralert 6   8   Random  0.78  0.66  0.7   0.66  0.68  0.75  1.97     0.08    2.04
# et/Main_Sentinel_padding_ralert 6   9   Random  0.79  0.67  0.72  0.67  0.69  0.76  1.98     0.08    2.06
# et/Main_Sentinel_padding_ralert 6   10  Random  0.79  0.66  0.71  0.66  0.68  0.76  1.99     0.08    2.06
# et/Main_Sentinel_padding_ralert 7   1   Random  0.78  0.66  0.7   0.66  0.67  0.75  1.98     0.08    2.06
# et/Main_Sentinel_padding_ralert 7   2   Random  0.78  0.66  0.71  0.66  0.68  0.75  1.98     0.08    2.06
# et/Main_Sentinel_padding_ralert 7   3   Random  0.78  0.66  0.71  0.66  0.68  0.75  1.99     0.08    2.07
# et/Main_Sentinel_padding_ralert 7   4   Random  0.79  0.67  0.71  0.67  0.69  0.76  2.04     0.08    2.12
# et/Main_Sentinel_padding_ralert 7   5   Random  0.79  0.66  0.69  0.66  0.67  0.75  2.0      0.08    2.07
# et/Main_Sentinel_padding_ralert 7   6   Random  0.78  0.66  0.7   0.66  0.67  0.75  1.98     0.08    2.06
# et/Main_Sentinel_padding_ralert 7   7   Random  0.78  0.65  0.7   0.65  0.67  0.75  1.97     0.08    2.05
# et/Main_Sentinel_padding_ralert 7   8   Random  0.78  0.65  0.69  0.65  0.67  0.75  2.0      0.08    2.08
# et/Main_Sentinel_padding_ralert 7   9   Random  0.79  0.66  0.7   0.66  0.67  0.76  2.0      0.08    2.08
# et/Main_Sentinel_padding_ralert 7   10  Random  0.79  0.68  0.71  0.68  0.69  0.76  2.0      0.08    2.07
# et/Main_Sentinel_padding_ralert 8   1   Random  0.78  0.64  0.68  0.64  0.66  0.74  1.98     0.08    2.06
# et/Main_Sentinel_padding_ralert 8   2   Random  0.79  0.66  0.71  0.66  0.68  0.76  1.98     0.08    2.06
# et/Main_Sentinel_padding_ralert 8   3   Random  0.79  0.67  0.72  0.67  0.68  0.76  2.0      0.08    2.08
# et/Main_Sentinel_padding_ralert 8   4   Random  0.78  0.65  0.68  0.65  0.66  0.74  1.99     0.08    2.06
# et/Main_Sentinel_padding_ralert 8   5   Random  0.79  0.66  0.7   0.66  0.67  0.75  1.96     0.08    2.04
# et/Main_Sentinel_padding_ralert 8   6   Random  0.79  0.67  0.72  0.67  0.69  0.76  2.01     0.08    2.09
# et/Main_Sentinel_padding_ralert 8   7   Random  0.79  0.66  0.7   0.66  0.68  0.76  2.0      0.08    2.08
# et/Main_Sentinel_padding_ralert 8   8   Random  0.78  0.66  0.69  0.66  0.67  0.75  2.0      0.08    2.08
# et/Main_Sentinel_padding_ralert 8   9   Random  0.78  0.66  0.7   0.66  0.68  0.75  1.98     0.08    2.06
# et/Main_Sentinel_padding_ralert 8   10  Random  0.78  0.65  0.69  0.65  0.67  0.75  1.97     0.08    2.05
# et/Main_Sentinel_padding_ralert 9   1   Random  0.78  0.65  0.69  0.65  0.67  0.75  2.01     0.08    2.09
# et/Main_Sentinel_padding_ralert 9   2   Random  0.78  0.66  0.7   0.66  0.68  0.75  2.04     0.08    2.12
# et/Main_Sentinel_padding_ralert 9   3   Random  0.78  0.66  0.69  0.66  0.67  0.75  2.01     0.08    2.08
# et/Main_Sentinel_padding_ralert 9   4   Random  0.78  0.66  0.7   0.66  0.67  0.75  1.99     0.08    2.07
# et/Main_Sentinel_padding_ralert 9   5   Random  0.79  0.68  0.71  0.68  0.69  0.76  1.97     0.08    2.05
# et/Main_Sentinel_padding_ralert 9   6   Random  0.78  0.66  0.71  0.66  0.68  0.75  2.01     0.08    2.09
# et/Main_Sentinel_padding_ralert 9   7   Random  0.79  0.67  0.71  0.67  0.68  0.75  2.01     0.08    2.09
# et/Main_Sentinel_padding_ralert 9   8   Random  0.78  0.65  0.71  0.65  0.67  0.75  2.0      0.08    2.08
# et/Main_Sentinel_padding_ralert 9   9   Random  0.78  0.66  0.7   0.66  0.67  0.75  1.98     0.08    2.06
# et/Main_Sentinel_padding_ralert 9   10  Random  0.79  0.65  0.69  0.65  0.67  0.75  2.05     0.08    2.13
#                    precision    recall  f1-score       support
# Aria                0.830696  0.765407  0.795227     52.000000
# D-LinkCam           0.875430  0.904495  0.889619    635.800000
# D-LinkDayCam        0.902557  0.797288  0.845877    123.500000
# D-LinkDevice        0.795864  0.823722  0.809491   1067.800000
# D-LinkSensor        0.482138  0.404019  0.439237    663.300000
# D-LinkSiren         0.422057  0.360111  0.388287    628.900000
# D-LinkSwitch        0.634131  0.621428  0.627440    661.400000
# D-LinkWaterSensor   0.460967  0.498651  0.478676    653.800000
# EdimaxCam           0.908886  0.783806  0.839747     89.600000
# EdimaxPlug1101W     0.521585  0.514553  0.515922    124.700000
# EdimaxPlug2101W     0.438161  0.406090  0.419581    113.100000
# EdnetCam            0.808433  0.609019  0.690615     39.000000
# EdnetGateway        0.799574  0.675206  0.730509     85.000000
# HomeMaticPlug       1.000000  0.955822  0.977202     63.900000
# Hue-Device          0.982599  0.990218  0.986392   3258.100000
# Lightify            0.626946  0.975060  0.763012    438.400000
# MAXGateway          0.950059  0.879448  0.912739     63.400000
# SmarterCoffee       0.232158  0.141278  0.167229     19.000000
# TP-LinkPlugHS100    0.630676  0.538372  0.578356     72.900000
# TP-LinkPlugHS110    0.587871  0.541820  0.560895     69.800000
# WeMoInsightSwitch   0.814027  0.822143  0.817845    607.700000
# WeMoLink            0.926861  0.851272  0.887356    676.900000
# WeMoSwitch          0.819284  0.822103  0.820483    460.700000
# Withings            0.903233  0.745790  0.815691     77.700000
# iKettle2            0.185070  0.093363  0.117351     18.800000
# accuracy            0.784911  0.784911  0.784911      0.784911
# macro avg           0.701570  0.660819  0.674991  10765.200000
# weighted avg        0.783168  0.784911  0.781301  10765.200000
